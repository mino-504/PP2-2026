# %% [markdown]
# # 나의 프로젝트 코드

# %% [markdown]
# 중요한 코드나 문서를 함께 작성할 거예요~
# - 작성일 : 2026.9.8
# - 작성자 : 최민호
#
# 그 외에 표나 그림 등도 넣을 수 있어요.

# %%
print("Hello, world!")
x = 3
print("x = ",x)
# Out:
# Hello, world!
# x =  3

# %% [markdown]
# 이 알고리즘은...

# %% [markdown]
# 이 알고리즘은 아주 간단합니다.
# 백트래킹 알고리즘을 사용하였으며, DPS 기법을 사용하였습니다.
